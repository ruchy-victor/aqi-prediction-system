# %% [markdown]
# <a href="https://colab.research.google.com/github/ruchy-victor/aqi-prediction-system/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Test")
# Out:
# Test
